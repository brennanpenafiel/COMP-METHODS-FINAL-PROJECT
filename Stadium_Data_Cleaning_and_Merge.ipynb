# %% [markdown]
# # Final Project

# %% [markdown]
# ## Initial Thoughts:
# - Merge football teams with duplicate names
#     - Teams that move locations
#     - Teams that do no have the same team name (the ID of the favorite team may not always refer to the same team)
# - Look at data to see which columns have enough data to conduct data analysis on
#     - Some games have no weather data
#     - Some stadiums have a lot of null information. Others are closed
# - Need to decide what year to cutoff the data (relevance)

# %%
import pandas as pd
import numpy as np

# %%
spreadspoke_df = pd.read_csv('NFL_sportsbetting_data/spreadspoke_scores.csv')
teams_df = pd.read_csv('NFL_sportsbetting_data/nfl_teams.csv')
stadiums_df = pd.read_csv('NFL_sportsbetting_data/nfl_stadiums.csv', encoding='ISO-8859-1')

# %%
spreadspoke_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14073 entries, 0 to 14072
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   schedule_date        14073 non-null  object
#  1   schedule_season      14073 non-null  int64
#  2   schedule_week        14073 non-null  object
#  3   schedule_playoff     14073 non-null  bool
#  4   team_home            14073 non-null  object
#  5   score_home           13801 non-null  float64
#  6   score_away           13801 non-null  float64
#  7   team_away            14073 non-null  object
#  8   team_favorite_id     11322 non-null  object
#  9   spread_favorite      11322 non-null  float64
#  10  over_under_line      11312 non-null  object
#  11  stadium              14073 non-null  object
#  12  stadium_neutral      14073 non-null  bool
#  13  weather_temperature  12525 non-null  float64
#  14  weather_wind_mph     12509 non-null  float64
#  15  weather_humidity     8476 non-null   float64
#  16  weather_detail       3127 non-null   object
# dtypes: bool(2), float64(6), int64(1), object(8)
# memory usage: 1.6+ MB

# %%
teams_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   team_name                44 non-null     object
#  1   team_name_short          44 non-null     object
#  2   team_id                  44 non-null     object
#  3   team_id_pfr              44 non-null     object
#  4   team_conference          44 non-null     object
#  5   team_division            35 non-null     object
#  6   team_conference_pre2002  44 non-null     object
#  7   team_division_pre2002    42 non-null     object
# dtypes: object(8)
# memory usage: 2.9+ KB

# %%
stadiums_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   stadium_name                     120 non-null    object
#  1   stadium_location                 119 non-null    object
#  2   stadium_open                     90 non-null     float64
#  3   stadium_close                    41 non-null     float64
#  4   stadium_type                     109 non-null    object
#  5   stadium_address                  102 non-null    object
#  6   stadium_weather_station_zipcode  101 non-null    object
#  7   stadium_weather_type             117 non-null    object
#  8   stadium_capacity                 54 non-null     object
#  9   stadium_surface                  68 non-null     object
#  10  stadium_weather_station          62 non-null     object
#  11  stadium_weather_station_name     63 non-null     object
#  12  stadium_latitude                 85 non-null     float64
#  13  stadium_longitude                85 non-null     float64
#  14  stadium_azimuthangle             59 non-null     float64
#  15  stadium_elevation                65 non-null     float64
# dtypes: float64(6), object(10)
# memory usage: 15.1+ KB

# %%
# display(spreadspoke_df)
# display(teams_df)
# display(stadiums_df)

# %%
#need to make sure that data has non null values for the betting data
spreadspoke_df = spreadspoke_df.dropna(subset=['team_favorite_id','spread_favorite','over_under_line'])

#converting the date column to datetimes
spreadspoke_df['schedule_date'] = pd.to_datetime(spreadspoke_df['schedule_date'], format='%m/%d/%Y')

#dropping games before 2002
spreadspoke_df = spreadspoke_df[spreadspoke_df['schedule_season'] >= 2002]

spreadspoke_df.head()
# Out:
#      schedule_date  schedule_season schedule_week  schedule_playoff  \
# 7872    2002-09-05             2002             1             False
# 7873    2002-09-08             2002             1             False
# 7874    2002-09-08             2002             1             False
# 7875    2002-09-08             2002             1             False
# 7876    2002-09-08             2002             1             False
#
#                team_home  score_home  score_away            team_away  \
# 7872     New York Giants        13.0        16.0  San Francisco 49ers
# 7873       Buffalo Bills        31.0        37.0        New York Jets
# 7874   Carolina Panthers        10.0         7.0     Baltimore Ravens
# 7875       Chicago Bears        27.0        23.0    Minnesota Vikings
# 7876  Cincinnati Bengals         6.0        34.0   San Diego Chargers
#
#      team_favorite_id  spread_favorite over_under_line  \
# 7872               SF             -4.0              39
# 7873              NYJ             -3.0              43
# 7874             PICK              0.0              33
# 7875              CHI             -4.5              41
# 7876              CIN             -3.0              37
#
#                            stadium  stadium_neutral  weather_temperature  \
# 7872                Giants Stadium            False                 75.0
# 7873          Ralph Wilson Stadium            False                 75.0
# 7874       Bank of America Stadium            False                 73.0
# 7875  Memorial Stadium (Champaign)            False                 76.0
# 7876            Paul Brown Stadium            False                 81.0
#
#       weather_wind_mph  weather_humidity weather_detail
# 7872              12.0              58.0            NaN
# 7873               7.0              50.0            NaN
# 7874               8.0              66.0            NaN
# 7875               5.0              75.0            NaN
# 7876               5.0              50.0            NaN

# %%
# Values to replace
values_to_replace = ['Washington Redskins', 'Washington Football Team']

# Replace specific values with 'New Team Name'
spreadspoke_df['team_home'] = spreadspoke_df['team_home'].replace(values_to_replace, 'Washington Commanders')  
spreadspoke_df['team_away'] = spreadspoke_df['team_away'].replace(values_to_replace, 'Washington Commanders')

# %%
nfl_teams = [
    "Arizona Cardinals",  "Atlanta Falcons",  "Baltimore Ravens",  "Buffalo Bills",  "Carolina Panthers",  "Chicago Bears",
    "Cincinnati Bengals", "Cleveland Browns", "Dallas Cowboys", "Denver Broncos", "Detroit Lions", "Green Bay Packers",
    "Houston Texans", "Indianapolis Colts",  "Jacksonville Jaguars",  "Kansas City Chiefs",  "Las Vegas Raiders",
    "Los Angeles Chargers",  "Los Angeles Rams",  "Miami Dolphins",  "Minnesota Vikings",  "New England Patriots",
    "New Orleans Saints",  "New York Giants",  "New York Jets",  "Philadelphia Eagles",  "Pittsburgh Steelers",
    "San Francisco 49ers",  "Seattle Seahawks",  "Tampa Bay Buccaneers",  "Tennessee Titans",  "Washington Commanders"
]

# Create regex pattern to match any of the NFL team names
pattern = r'\b(' + '|'.join(nfl_teams) + r')\b'

# Filter the DataFrame to only keep rows that contain an NFL team name
filtered_df = spreadspoke_df[spreadspoke_df['team_home'].str.contains(pattern, case=False, regex=True)]
spreadspoke_df2 = filtered_df[filtered_df['team_away'].str.contains(pattern, case=False, regex=True)]

# Display the filtered DataFrame
spreadspoke_df2.head()

#we don't lose washington commanders as the home team here
len(list(spreadspoke_df2['team_home'].unique()))
# Out:
# C:\Users\2024.WK5CG0217Y8KMID\AppData\Local\Temp\ipykernel_5952\1728587709.py:14: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   filtered_df = spreadspoke_df[spreadspoke_df['team_home'].str.contains(pattern, case=False, regex=True)]
# C:\Users\2024.WK5CG0217Y8KMID\AppData\Local\Temp\ipykernel_5952\1728587709.py:15: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   spreadspoke_df2 = filtered_df[filtered_df['team_away'].str.contains(pattern, case=False, regex=True)]
# 32

# %%
#replace washington redskins and washington football team with washington commanders
spreadspoke_df2.loc[spreadspoke_df2['team_home'].isin(values_to_replace), 'team_home'] = 'Washington Commanders'
spreadspoke_df2.loc[spreadspoke_df2['team_away'].isin(values_to_replace), 'team_away'] = 'Washington Commanders'

#prove that it was replaced correctly
spreadspoke_df2.query("team_away == 'Washington Commanders'")
spreadspoke_df2.query("team_home == 'Washington Commanders'")
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 7886     2002-09-08             2002             1             False
# 7903     2002-09-16             2002             2             False
# 7958     2002-10-13             2002             6             False
# 7986     2002-10-27             2002             8             False
# 8078     2002-12-08             2002            14             False
# ...             ...              ...           ...               ...
# 13636    2023-10-29             2023             8             False
# 13678    2023-11-19             2023            11             False
# 13707    2023-12-03             2023            13             False
# 13771    2023-12-31             2023            17             False
# 13787    2024-01-07             2023            18             False
#
#                    team_home  score_home  score_away            team_away  \
# 7886   Washington Commanders        31.0        23.0    Arizona Cardinals
# 7903   Washington Commanders         7.0        37.0  Philadelphia Eagles
# 7958   Washington Commanders        27.0        43.0   New Orleans Saints
# 7986   Washington Commanders        26.0        21.0   Indianapolis Colts
# 8078   Washington Commanders        21.0        27.0      New York Giants
# ...                      ...         ...         ...                  ...
# 13636  Washington Commanders        31.0        38.0  Philadelphia Eagles
# 13678  Washington Commanders        19.0        31.0      New York Giants
# 13707  Washington Commanders        15.0        45.0       Miami Dolphins
# 13771  Washington Commanders        10.0        27.0  San Francisco 49ers
# 13787  Washington Commanders        10.0        38.0       Dallas Cowboys
#
#       team_favorite_id  spread_favorite over_under_line      stadium  \
# 7886               WAS             -6.0            44.5  FedEx Field
# 7903               PHI             -3.0              44  FedEx Field
# 7958                NO             -1.5            45.5  FedEx Field
# 7986               WAS             -1.0              46  FedEx Field
# 8078               WAS             -3.0            37.5  FedEx Field
# ...                ...              ...             ...          ...
# 13636              PHI             -7.0              43  FedEx Field
# 13678              WAS             -8.5              39  FedEx Field
# 13707              MIA             -9.0            49.5  FedEx Field
# 13771               SF            -14.0            48.5  FedEx Field
# 13787              DAL            -13.0            47.5  FedEx Field
#
#        stadium_neutral  weather_temperature  weather_wind_mph  \
# 7886             False                 73.0               5.0
# 7903             False                 75.0              12.0
# 7958             False                 65.0               7.0
# 7986             False                 58.0               8.0
# 8078             False                 36.0               6.0
# ...                ...                  ...               ...
# 13636            False                  NaN               NaN
# 13678            False                  NaN               NaN
# 13707            False                  NaN               NaN
# 13771            False                  NaN               NaN
# 13787            False                  NaN               NaN
#
#        weather_humidity weather_detail
# 7886               70.0            NaN
# 7903               84.0            NaN
# 7958               92.0            NaN
# 7986               74.0            NaN
# 8078               70.0            NaN
# ...                 ...            ...
# 13636               NaN            NaN
# 13678               NaN            NaN
# 13707               NaN            NaN
# 13771               NaN            NaN
# 13787               NaN            NaN
#
# [171 rows x 17 columns]

# %%
#Matching teams to stadiums:

#list of current stadiums that are open (including stadiums that have had multiple names since 2002)
stadiums = [
    "Acrisure Stadium", "Allegiant Stadium", "GEHA Field at Arrowhead Stadium", "AT&T Stadium", "Bank of America Stadium",
    "Caesars Superdome", "Empower Field at Mile High", "FedEx Field","FirstEnergy Stadium", "Ford Field", "Gillette Stadium",
    "Hard Rock Stadium", "Highmark Stadium", "Lambeau Field", "Levi's Stadium", "Lincoln Financial Field","Lumen Field",
    "M&T Bank Stadium", "Mercedes-Benz Stadium", "MetLife Stadium", "NRG Stadium", "Nissan Stadium", "Paycor Stadium",
    "Raymond James Stadium", "SoFi Stadium", "Soldier Field", "State Farm Stadium", "TIAA Bank Field", "U.S. Bank Stadium",
    "Lucas Oil Stadium",
    "Cowboys Stadium","Sports Authority Field at Mile High","Mile High Stadium","University of Phoenix Stadium",
    "Reliant Stadium", "EverBank Field", "Arrowhead Stadium", "LP Stadium", "Louisiana Superdome",
    "Mercedes-Benz Superdome","Bills Stadium", "New Era Field","Ralph Wilson Stadium", "Heinz Field"]

pattern = r'\b(' + '|'.join(stadiums) + r')\b'
stadiums_filtered_df = stadiums_df[stadiums_df['stadium_name'].str.contains(pattern, case=False, regex=True)]
stadiums_filtered_df = stadiums_filtered_df.drop(columns=['stadium_close', 'stadium_address', 'stadium_weather_station_zipcode', 'stadium_weather_station',	'stadium_weather_station_name', 'stadium_azimuthangle', 'stadium_elevation']).reset_index().drop(columns=['index'])
stadiums_filtered_df
# Out:
# C:\Users\2024.WK5CG0217Y8KMID\AppData\Local\Temp\ipykernel_5952\763062031.py:16: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   stadiums_filtered_df = stadiums_df[stadiums_df['stadium_name'].str.contains(pattern, case=False, regex=True)]
#                            stadium_name     stadium_location  stadium_open  \
# 0                          AT&T Stadium        Arlington, TX        2009.0
# 1                       Cowboys Stadium        Arlington, TX        2009.0
# 2                 Mercedes-Benz Stadium          Atlanta, GA        2017.0
# 3                      M&T Bank Stadium        Baltimore, MD        1998.0
# 4               Bank of America Stadium        Charlotte, NC        1996.0
# 5                         Soldier Field          Chicago, IL        1926.0
# 6                        Paycor Stadium       Cincinnati, OH        2000.0
# 7                   FirstEnergy Stadium        Cleveland, OH        1999.0
# 8            Empower Field at Mile High           Denver, CO        2001.0
# 9                     Mile High Stadium           Denver, CO        1960.0
# 10  Sports Authority Field at Mile High           Denver, CO        2001.0
# 11                           Ford Field          Detroit, MI        2002.0
# 12                      MetLife Stadium  East Rutherford, NJ        2010.0
# 13                     Gillette Stadium       Foxborough, MA        2002.0
# 14                   State Farm Stadium         Glendale, AZ        2006.0
# 15        University of Phoenix Stadium         Glendale, AZ        2006.0
# 16                        Lambeau Field        Green Bay, WI        1957.0
# 17                          NRG Stadium          Houston, TX        2002.0
# 18                      Reliant Stadium          Houston, TX        2002.0
# 19                    Lucas Oil Stadium     Indianapolis, IN        2008.0
# 20                         SoFi Stadium        Inglewood, CA        2020.0
# 21                       EverBank Field     Jacksonville, FL        1995.0
# 22                      TIAA Bank Field     Jacksonville, FL        1995.0
# 23                    Arrowhead Stadium      Kansas City, MO        1972.0
# 24      GEHA Field at Arrowhead Stadium      Kansas City, MO        1972.0
# 25                          FedEx Field         Landover, MD        1997.0
# 26                    Hard Rock Stadium    Miami Gardens, FL        1987.0
# 27                    U.S. Bank Stadium      Minneapolis, MN        2016.0
# 28                           LP Stadium        Nashville, TN        1999.0
# 29                       Nissan Stadium        Nashville, TN        1999.0
# 30                    Caesars Superdome      New Orleans, LA        1975.0
# 31                  Louisiana Superdome      New Orleans, LA        1975.0
# 32              Mercedes-Benz Superdome      New Orleans, LA        1975.0
# 33                        Bills Stadium     Orchard Park, NY        1973.0
# 34                     Highmark Stadium     Orchard Park, NY        1973.0
# 35                        New Era Field     Orchard Park, NY        1973.0
# 36                 Ralph Wilson Stadium     Orchard Park, NY        1973.0
# 37                    Allegiant Stadium         Paradise, NV        2020.0
# 38              Lincoln Financial Field     Philadelphia, PA        2003.0
# 39                     Acrisure Stadium       Pittsburgh, PA        2001.0
# 40                          Heinz Field       Pittsburgh, PA        2001.0
# 41                       Levi's Stadium      Santa Clara, CA        2014.0
# 42                          Lumen Field          Seattle, WA        2002.0
# 43                Raymond James Stadium            Tampa, FL        1998.0
#
#    stadium_type stadium_weather_type stadium_capacity     stadium_surface  \
# 0   retractable               indoor           80,000           FieldTurf
# 1   retractable               indoor           80,000           FieldTurf
# 2   retractable               indoor            71000           FieldTurf
# 3       outdoor             moderate           71,008           FieldTurf
# 4       outdoor             moderate           73,778               Grass
# 5       outdoor                 cold           61,500               Grass
# 6       outdoor                 cold           65,515           FieldTurf
# 7       outdoor                 cold           68,000               Grass
# 8       outdoor                 cold           76,125               Grass
# 9       outdoor                 cold              NaN                 NaN
# 10      outdoor                 cold           76,125               Grass
# 11       indoor               indoor           65,000           FieldTurf
# 12      outdoor                 cold           82,500           FieldTurf
# 13      outdoor                 cold           68,756           FieldTurf
# 14  retractable               indoor           63,400               Grass
# 15  retractable               indoor           63,400               Grass
# 16      outdoor                 cold           80,735               Grass
# 17  retractable               indoor           71,500               Grass
# 18  retractable               indoor           71,500               Grass
# 19  retractable               indoor           63,000           FieldTurf
# 20      outdoor                 warm            70240  Hellas Matrix Turf
# 21      outdoor                 warm           67,264               Grass
# 22      outdoor                 warm           67,264               Grass
# 23      outdoor                 cold           76,416               Grass
# 24      outdoor                 cold           76,416               Grass
# 25      outdoor             moderate           79,000               Grass
# 26      outdoor                 warm           65,326               Grass
# 27       indoor               indoor           66,200           FieldTurf
# 28      outdoor             moderate           69,143               Grass
# 29      outdoor             moderate           69,143               Grass
# 30       indoor               indoor           76,468           FieldTurf
# 31       indoor               indoor           76,468           FieldTurf
# 32       indoor               indoor           76,468           FieldTurf
# 33      outdoor                 cold           73,967           FieldTurf
# 34      outdoor                 cold           73,967           FieldTurf
# 35      outdoor                 cold           73,967           FieldTurf
# 36      outdoor                 cold           73,967           FieldTurf
# 37       indoor               indoor            65000               Grass
# 38      outdoor                 cold           69,176               Grass
# 39      outdoor                 cold           65,500               Grass
# 40      outdoor                 cold           65,500               Grass
# 41      outdoor             moderate           68,500               Grass
# 42      outdoor             moderate           67,000           FieldTurf
# 43      outdoor                 warm           65,890               Grass
#
#     stadium_latitude  stadium_longitude
# 0          32.747778         -97.092778
# 1          32.757200         -97.073600
# 2          33.755556         -84.400000
# 3          39.278056         -76.622778
# 4          35.225833         -80.852778
# 5          41.862300         -87.616700
# 6          39.100000         -84.516670
# 7          41.506111         -81.699444
# 8          39.743889        -105.020000
# 9          39.746111        -105.021667
# 10         39.763300        -104.869400
# 11         42.340000         -83.045556
# 12         40.813528         -74.074361
# 13         42.091000         -71.264000
# 14         33.528000        -112.263000
# 15         33.455200        -111.931600
# 16         44.501389         -88.062222
# 17         29.684722         -95.410833
# 18         29.638060         -95.281940
# 19         39.760056         -86.162806
# 20         33.953450        -118.339200
# 21         30.233330         -81.666670
# 22         30.323889         -81.637500
# 23         39.048889         -94.483889
# 24         39.048889         -94.483889
# 25         38.907778         -76.864444
# 26         25.958056         -80.238889
# 27         44.973889         -93.258056
# 28         36.118890         -86.689170
# 29         36.166389         -86.771389
# 30               NaN                NaN
# 31               NaN                NaN
# 32         29.950833         -90.811111
# 33         42.889000         -78.890100
# 34         42.889000         -78.890100
# 35         42.774000         -78.787000
# 36         42.889000         -78.890100
# 37         36.090750        -115.183722
# 38         39.900833         -75.167500
# 39         40.484600         -80.214400
# 40         40.446667         -80.015833
# 41         37.403000        -121.970000
# 42         47.652300        -122.409500
# 43         27.975833         -82.503333

# %%
#add a column to the spreadspoke_df to match the hometown to the home team
stadium_locations = {'Pittsburgh Steelers':'Pittsburgh, PA', 'Las Vegas Raiders':'Paradise, NV', 'Dallas Cowboys':'Arlington, TX',
                     'Carolina Panthers':'Charlotte, NC', 'New Orleans Saints':'New Orleans, LA', 'Denver Broncos':'Denver, CO',
                     'Washington Commanders':'Landover, MD', 'Cleveland Browns':'Cleveland, OH', 'Detroit Lions':'Detroit, MI',
                     'Kansas City Chiefs':'Kansas City, MO', 'New England Patriots':'Foxborough, MA', 
                     'Miami Dolphins':'Miami Gardens, FL', 'Buffalo Bills':'Orchard Park, NY', 'Green Bay Packers':'Green Bay, WI',
                     'San Francisco 49ers':'Santa Clara, CA', 'Philadelphia Eagles':'Philadelphia, PA', 
                     'Indianapolis Colts':'Indianapolis, IN', 'Seattle Seahawks':'Seattle, WA', 'Baltimore Ravens':'Baltimore, MD',
                     'Atlanta Falcons':'Atlanta, GA', 'New York Giants':'East Rutherford, NJ', 'New York Jets':'East Rutherford, NJ',
                     'Tennessee Titans':'Nashville, TN', 'Houston Texans':'Houston, TX', 'Cincinnati Bengals':'Cincinnati, OH',
                     'Tampa Bay Buccaneers':'Tampa, FL', 'Los Angeles Chargers':'Inglewood, CA', 'Los Angeles Rams':'Inglewood, CA',
                     'Chicago Bears':'Chicago, IL', 'Arizona Cardinals':'Glendale, AZ', 'Jacksonville Jaguars':'Jacksonville, FL',
                     'Minnesota Vikings':'Minneapolis, MN'}

spreadspoke_df2['stadium_location'] = spreadspoke_df2['team_home'].map(stadium_locations) #this is where you lose the commanders
spreadspoke_df2.reset_index()
spreadspoke_df2.head()
# Out:
# C:\Users\2024.WK5CG0217Y8KMID\AppData\Local\Temp\ipykernel_5952\3396990784.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spreadspoke_df2['stadium_location'] = spreadspoke_df2['team_home'].map(stadium_locations) #this is where you lose the commanders
#      schedule_date  schedule_season schedule_week  schedule_playoff  \
# 7872    2002-09-05             2002             1             False
# 7873    2002-09-08             2002             1             False
# 7874    2002-09-08             2002             1             False
# 7875    2002-09-08             2002             1             False
# 7877    2002-09-08             2002             1             False
#
#               team_home  score_home  score_away            team_away  \
# 7872    New York Giants        13.0        16.0  San Francisco 49ers
# 7873      Buffalo Bills        31.0        37.0        New York Jets
# 7874  Carolina Panthers        10.0         7.0     Baltimore Ravens
# 7875      Chicago Bears        27.0        23.0    Minnesota Vikings
# 7877   Cleveland Browns        39.0        40.0   Kansas City Chiefs
#
#      team_favorite_id  spread_favorite over_under_line  \
# 7872               SF             -4.0              39
# 7873              NYJ             -3.0              43
# 7874             PICK              0.0              33
# 7875              CHI             -4.5              41
# 7877              CLE             -2.0              36
#
#                            stadium  stadium_neutral  weather_temperature  \
# 7872                Giants Stadium            False                 75.0
# 7873          Ralph Wilson Stadium            False                 75.0
# 7874       Bank of America Stadium            False                 73.0
# 7875  Memorial Stadium (Champaign)            False                 76.0
# 7877           FirstEnergy Stadium            False                 78.0
#
#       weather_wind_mph  weather_humidity weather_detail     stadium_location
# 7872              12.0              58.0            NaN  East Rutherford, NJ
# 7873               7.0              50.0            NaN     Orchard Park, NY
# 7874               8.0              66.0            NaN        Charlotte, NC
# 7875               5.0              75.0            NaN          Chicago, IL
# 7877               7.0              54.0            NaN        Cleveland, OH

# %%
#merge the stadium dataframe to the spreadspoke dataframe to get the stadium information in the same df as the game information
spreadspoke_df3 = pd.merge(spreadspoke_df2, stadiums_filtered_df, on='stadium_location', how='outer')

#create a mask to filter rows for games played in stadiums that no longer exist
mask = spreadspoke_df3['schedule_season'] >= spreadspoke_df3['stadium_open']
spreadspoke_df3 = spreadspoke_df3[mask]

#need to see all of the columns
pd.set_option('display.max_columns', None)

#check for the Los Angeles Chargers
#check for the Los Angeles Rams
#check for the Las Vegas Raiders
spreadspoke_df3.query("team_home == 'Los Angeles Chargers'").head(5)
spreadspoke_df3.query("team_home == 'Los Angeles Rams'").head(5)
#spreadspoke_df3.query("team_home == 'Las Vegas Raiders'").head(5)
# Out:
#      schedule_date  schedule_season schedule_week  schedule_playoff  \
# 7481    2020-09-13             2020             1             False
# 7484    2020-10-04             2020             4             False
# 7486    2020-10-26             2020             7             False
# 7488    2020-11-15             2020            10             False
# 7490    2020-11-29             2020            12             False
#
#              team_home  score_home  score_away            team_away  \
# 7481  Los Angeles Rams        20.0        17.0       Dallas Cowboys
# 7484  Los Angeles Rams        17.0         9.0      New York Giants
# 7486  Los Angeles Rams        24.0        10.0        Chicago Bears
# 7488  Los Angeles Rams        23.0        16.0     Seattle Seahawks
# 7490  Los Angeles Rams        20.0        23.0  San Francisco 49ers
#
#      team_favorite_id  spread_favorite over_under_line       stadium  \
# 7481              DAL             -2.0            51.5  SoFi Stadium
# 7484              LAR            -13.0            48.5  SoFi Stadium
# 7486              LAR             -6.0              45  SoFi Stadium
# 7488              LAR             -3.0            54.5  SoFi Stadium
# 7490              LAR             -6.5            44.5  SoFi Stadium
#
#       stadium_neutral  weather_temperature  weather_wind_mph  \
# 7481            False                 72.0               0.0
# 7484            False                 72.0               0.0
# 7486            False                 72.0               0.0
# 7488            False                 72.0               0.0
# 7490            False                 72.0               0.0
#
#       weather_humidity weather_detail stadium_location  stadium_name  \
# 7481               NaN         indoor    Inglewood, CA  SoFi Stadium
# 7484               NaN         indoor    Inglewood, CA  SoFi Stadium
# 7486               NaN         indoor    Inglewood, CA  SoFi Stadium
# 7488               NaN         indoor    Inglewood, CA  SoFi Stadium
# 7490               NaN         indoor    Inglewood, CA  SoFi Stadium
#
#       stadium_open stadium_type stadium_weather_type stadium_capacity  \
# 7481        2020.0      outdoor                 warm            70240
# 7484        2020.0      outdoor                 warm            70240
# 7486        2020.0      outdoor                 warm            70240
# 7488        2020.0      outdoor                 warm            70240
# 7490        2020.0      outdoor                 warm            70240
#
#          stadium_surface  stadium_latitude  stadium_longitude
# 7481  Hellas Matrix Turf          33.95345          -118.3392
# 7484  Hellas Matrix Turf          33.95345          -118.3392
# 7486  Hellas Matrix Turf          33.95345          -118.3392
# 7488  Hellas Matrix Turf          33.95345          -118.3392
# 7490  Hellas Matrix Turf          33.95345          -118.3392

# %%
#check to make sure we didn't lose any stadiums during the merge
unique_stadiums = spreadspoke_df3['stadium_name'].unique()

#the number of stadiums stays the same (we didn't lose any)
print(len(stadiums)) #44
print(len(unique_stadiums)) #44
# Out:
# 44
# 44

# %%
final_df = spreadspoke_df3.reset_index().drop(columns=['index'])
final_df
#final_df contains a combination of the stadium data and the game data
# Out:
#      schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0       2010-09-12             2010             1             False
# 1       2010-09-13             2010             1             False
# 2       2010-09-19             2010             2             False
# 3       2010-09-26             2010             3             False
# 4       2010-10-03             2010             4             False
# ...            ...              ...           ...               ...
# 6865    2023-11-12             2023            10             False
# 6866    2023-11-26             2023            12             False
# 6867    2023-12-10             2023            14             False
# 6868    2023-12-14             2023            15             False
# 6869    2024-01-07             2023            18             False
#
#               team_home  score_home  score_away             team_away  \
# 0       New York Giants        31.0        18.0     Carolina Panthers
# 1         New York Jets         9.0        10.0      Baltimore Ravens
# 2         New York Jets        28.0        14.0  New England Patriots
# 3       New York Giants        10.0        29.0      Tennessee Titans
# 4       New York Giants        17.0         3.0         Chicago Bears
# ...                 ...         ...         ...                   ...
# 6865  Las Vegas Raiders        16.0        12.0         New York Jets
# 6866  Las Vegas Raiders        17.0        31.0    Kansas City Chiefs
# 6867  Las Vegas Raiders         0.0         3.0     Minnesota Vikings
# 6868  Las Vegas Raiders        63.0        21.0  Los Angeles Chargers
# 6869  Las Vegas Raiders        27.0        14.0        Denver Broncos
#
#      team_favorite_id  spread_favorite over_under_line            stadium  \
# 0                 NYG             -6.0              41    MetLife Stadium
# 1                 NYJ             -1.0            36.5    MetLife Stadium
# 2                  NE             -3.0            39.5    MetLife Stadium
# 3                 NYG             -3.0            43.5    MetLife Stadium
# 4                 NYG             -3.5              44    MetLife Stadium
# ...               ...              ...             ...                ...
# 6865              NYJ             -1.0            35.5  Allegiant Stadium
# 6866               KC             -9.0            42.5  Allegiant Stadium
# 6867              MIN             -3.0            40.5  Allegiant Stadium
# 6868              LVR             -3.0            35.5  Allegiant Stadium
# 6869              LVR             -3.5            37.5  Allegiant Stadium
#
#       stadium_neutral  weather_temperature  weather_wind_mph  \
# 0               False                 65.0               1.0
# 1               False                 73.0               1.0
# 2               False                 82.0               6.0
# 3               False                 70.0               3.0
# 4               False                 59.0               1.0
# ...               ...                  ...               ...
# 6865            False                 72.0               0.0
# 6866            False                 72.0               0.0
# 6867            False                 72.0               0.0
# 6868            False                 72.0               0.0
# 6869            False                 72.0               0.0
#
#       weather_humidity weather_detail     stadium_location       stadium_name  \
# 0                 67.0           rain  East Rutherford, NJ    MetLife Stadium
# 1                100.0           rain  East Rutherford, NJ    MetLife Stadium
# 2                 36.0            NaN  East Rutherford, NJ    MetLife Stadium
# 3                 48.0            NaN  East Rutherford, NJ    MetLife Stadium
# 4                 52.0            NaN  East Rutherford, NJ    MetLife Stadium
# ...                ...            ...                  ...                ...
# 6865               NaN         indoor         Paradise, NV  Allegiant Stadium
# 6866               NaN         indoor         Paradise, NV  Allegiant Stadium
# 6867               NaN         indoor         Paradise, NV  Allegiant Stadium
# 6868               NaN         indoor         Paradise, NV  Allegiant Stadium
# 6869               NaN         indoor         Paradise, NV  Allegiant Stadium
#
#       stadium_open stadium_type stadium_weather_type stadium_capacity  \
# 0           2010.0      outdoor                 cold           82,500
# 1           2010.0      outdoor                 cold           82,500
# 2           2010.0      outdoor                 cold           82,500
# 3           2010.0      outdoor                 cold           82,500
# 4           2010.0      outdoor                 cold           82,500
# ...            ...          ...                  ...              ...
# 6865        2020.0       indoor               indoor            65000
# 6866        2020.0       indoor               indoor            65000
# 6867        2020.0       indoor               indoor            65000
# 6868        2020.0       indoor               indoor            65000
# 6869        2020.0       indoor               indoor            65000
#
#      stadium_surface  stadium_latitude  stadium_longitude
# 0          FieldTurf         40.813528         -74.074361
# 1          FieldTurf         40.813528         -74.074361
# 2          FieldTurf         40.813528         -74.074361
# 3          FieldTurf         40.813528         -74.074361
# 4          FieldTurf         40.813528         -74.074361
# ...              ...               ...                ...
# 6865           Grass         36.090750        -115.183722
# 6866           Grass         36.090750        -115.183722
# 6867           Grass         36.090750        -115.183722
# 6868           Grass         36.090750        -115.183722
# 6869           Grass         36.090750        -115.183722
#
# [6870 rows x 26 columns]
